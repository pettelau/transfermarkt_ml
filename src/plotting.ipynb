# %%
import pandas as pd
import numpy as np
import seaborn as sns                       #visualisation
import matplotlib.pyplot as plt             #visualisation
# %matplotlib inline     
sns.set(color_codes=True)

# %%
df = pd.read_csv("./archive/players.csv")
df.head(5)
# Out:
#    player_id                name  current_club_id   current_club_name  \
# 0     134354     Ian Raeymaekers              498         Ksc Lokeren
# 1      99946      Mohamed Camara             1095        Es Troyes Ac
# 2      76948       Pablo Olivera              979       Moreirense Fc
# 3     108372      Aliosman Aydin               38  Fortuna Dusseldorf
# 4      78820  Jaime Alfonso Ruiz              354         Kv Mechelen
#
#   country_of_citizenship country_of_birth city_of_birth date_of_birth  \
# 0                Belgium          Belgium       Aalst      1995-01-30
# 1                 Guinea           Guinea     Conakry      1990-09-20
# 2                Uruguay          Uruguay        Melo      1987-12-08
# 3                 Turkey          Germany    Dormagen      1992-02-06
# 4               Colombia         Colombia        Cali      1984-01-03
#
#   position    sub_position  ... highest_market_value_in_eur  agent_name  \
# ...

# %%
df.count()
# Out:
# player_id                               28371
# name                                    28371
# current_club_id                         28371
# current_club_name                       28371
# country_of_citizenship                  28370
# country_of_birth                        26496
# city_of_birth                           26509
# date_of_birth                           28336
# position                                28371
# sub_position                            24935
# foot                                    26162
# height_in_cm                            28371
# market_value_in_eur                     19418
# highest_market_value_in_eur             27309
# agent_name                              17349
# contract_expiration_date                17034
# current_club_domestic_competition_id    28371
# first_name                              26610
# last_name                               28371
# player_code                             28371
# ...

# %%
df.dtypes
# Out:
# player_id                                 int64
# name                                     object
# current_club_id                           int64
# current_club_name                        object
# country_of_citizenship                   object
# country_of_birth                         object
# city_of_birth                            object
# date_of_birth                            object
# position                                 object
# sub_position                             object
# foot                                     object
# height_in_cm                              int64
# market_value_in_eur                     float64
# highest_market_value_in_eur             float64
# agent_name                               object
# contract_expiration_date                 object
# current_club_domestic_competition_id     object
# first_name                               object
# last_name                                object
# player_code                              object
# ...

# %%
df.isnull().sum()
# Out:
# player_id                                   0
# name                                        0
# current_club_id                             0
# current_club_name                           0
# country_of_citizenship                      1
# country_of_birth                         1875
# city_of_birth                            1862
# date_of_birth                              35
# position                                    0
# sub_position                             3436
# foot                                     2209
# height_in_cm                                0
# market_value_in_eur                      8953
# highest_market_value_in_eur              1062
# agent_name                              11022
# contract_expiration_date                11337
# current_club_domestic_competition_id        0
# first_name                               1761
# last_name                                   0
# player_code                                 0
# ...

# %%
df[df['country_of_citizenship'].isnull()]
# Out:
#       player_id              name  current_club_id  current_club_name  \
# 3973     345068  Abdullah Karakoc             3216  Mersin Idmanyurdu
#
#      country_of_citizenship country_of_birth city_of_birth date_of_birth  \
# 3973                    NaN          Germany        Köln             NaN
#
#       position sub_position  ... highest_market_value_in_eur  agent_name  \
# 3973  Defender  Centre-Back  ...                    100000.0         NaN
#
#       contract_expiration_date  current_club_domestic_competition_id  \
# 3973                       NaN                                   TR1
#
#      first_name last_name       player_code  \
# 3973   Abdullah   Karakoc  abdullah-karakoc
#
#                                               image_url last_season  \
# 3973  https://img.a.transfermarkt.technology/portrai...        2014
#
#                                                     url
# 3973  https://www.transfermarkt.co.uk/abdullah-karak...
#
# [1 rows x 23 columns]

# %%
sns.boxplot(x=df['highest_market_value_in_eur'], showfliers = False)
# Out:
# <AxesSubplot:xlabel='highest_market_value_in_eur'>

# %%
# 2022 - int(pd.to_datetime(df['date_of_birth'], errors='coerce').dt.year)

# df["age"] = 2022 - int(pd.to_datetime(df['date_of_birth'], errors='coerce').dt.year)

df['date_of_birth'] = pd.to_datetime(df['date_of_birth'])

df['age'] = (pd.to_datetime('today') - df['date_of_birth']).astype('<m8[Y]')

# %%
df[df['age']>45]
# Out:
# Empty DataFrame
# Columns: [player_id, name, current_club_id, current_club_name, country_of_citizenship, country_of_birth, city_of_birth, date_of_birth, position, sub_position, foot, height_in_cm, market_value_in_eur, highest_market_value_in_eur, agent_name, contract_expiration_date, current_club_domestic_competition_id, first_name, last_name, player_code, image_url, last_season, url, age]
# Index: []
#
# [0 rows x 24 columns]

# %%
# df.drop(df[df.age > 42].index, inplace=True)

# %%
fig, ax = plt.subplots(figsize=(10,6))
ax.scatter(pd.to_datetime(df['date_of_birth'], errors='coerce').dt.year, df['highest_market_value_in_eur'])
ax.set_xlabel('Date of birth')
ax.set_ylabel('Highest market value')
plt.show()

# %%
sns.set(rc={'figure.figsize':(11,8.27)})

sns.boxplot(x="age", y="market_value_in_eur", data=df)
# Out:
# <AxesSubplot:xlabel='age', ylabel='market_value_in_eur'>

# %%
corr = df.corr()

sns.heatmap(corr, xticklabels=corr.columns, yticklabels=corr.columns)
# Out:
# <AxesSubplot:>

# %%
# 499 999 og under
under_500k = df.drop(df[df.market_value_in_eur >= 500000].index)
under_500k.count()
# Out:
# player_id                               19772
# name                                    19772
# current_club_id                         19772
# current_club_name                       19772
# country_of_citizenship                  19771
# country_of_birth                        18041
# city_of_birth                           18053
# date_of_birth                           19738
# position                                19772
# sub_position                            17075
# foot                                    17738
# height_in_cm                            19772
# market_value_in_eur                     11339
# highest_market_value_in_eur             18732
# agent_name                              10423
# contract_expiration_date                 9654
# current_club_domestic_competition_id    19772
# first_name                              18626
# last_name                               19772
# player_code                             19772
# ...

# %%
df.count()
# Out:
# player_id                               27803
# name                                    27803
# current_club_id                         27803
# current_club_name                       27803
# country_of_citizenship                  27802
# country_of_birth                        25935
# city_of_birth                           25948
# date_of_birth                           27768
# position                                27803
# sub_position                            24529
# foot                                    25659
# height_in_cm                            27803
# market_value_in_eur                     19370
# highest_market_value_in_eur             26746
# agent_name                              17157
# contract_expiration_date                17030
# current_club_domestic_competition_id    27803
# first_name                              26095
# last_name                               27803
# player_code                             27803
# ...

# %%
# 500 000 og over
over_500k = df.drop(df[df.market_value_in_eur < 500000].index)
over_500k.count()
# Out:
# player_id                               16464
# name                                    16464
# current_club_id                         16464
# current_club_name                       16464
# country_of_citizenship                  16463
# country_of_birth                        15402
# city_of_birth                           15410
# date_of_birth                           16435
# position                                16464
# sub_position                            14763
# foot                                    15087
# height_in_cm                            16464
# market_value_in_eur                      8031
# highest_market_value_in_eur             15476
# agent_name                               9544
# contract_expiration_date                 9024
# current_club_domestic_competition_id    16464
# first_name                              15392
# last_name                               16464
# player_code                             16464
# ...

# %%
active_players = df[df['last_season']==2022]

over40 = active_players[active_players['age']>40]

over40
# Out:
#        player_id                name  current_club_id   current_club_name  \
# 23100       3455  Zlatan Ibrahimović                5          Ac Mailand
# 23542      21872     Gianluca Pegolo             6574         Us Sassuolo
# 23832       9422      Allan McGregor              124     Glasgow Rangers
# 24252      19948     Willy Caballero              180      Fc Southampton
# 26256       5578   Nicolas Penneteau             1421         Stade Reims
# 26332      44177      Rafael Bracali             2503   Boavista Porto Fc
# 27585      34370         Diego López              367      Rayo Vallecano
# 28113       7663             Joaquín              150  Real Betis Sevilla
#
#       country_of_citizenship country_of_birth               city_of_birth  \
# 23100                 Sweden           Sweden                     Malmö
# 23542                  Italy            Italy        Bassano del Grappa
# 23832               Scotland         Scotland                 Edinburgh
# ...

# %%
over45 = df[df['age']>41]
over45
# Out:
#        player_id                      name  current_club_id  \
# 7          12840              Steven Milne              511
# 84         35259            Valentin Iliev             4482
# 93         87864  Mohamed Achraf Khalfaoui             6994
# 98         49022           Vitaliy Rudenko             6994
# 112         1772                 Du-ri Cha               38
# ...          ...                       ...              ...
# 14508      15220               Artur Boruc              989
# 15586      29178                      Nino             1531
# 15846      85270        Pier Graziano Gori             4171
# 17651      25035           Sergey Ryzhikov            41201
# 18195      12811               Dave Mackay              511
#
#                    current_club_name country_of_citizenship country_of_birth  \
# 7                          Dundee Fc               Scotland         Scotland
# 84                       Volyn Lutsk               Bulgaria         Bulgaria
# ...
